# %% [markdown]
# # Assignment 3
#
# ### Instructions
# 1. Import the following modules:
#     - `pandas`
#     - `stats` from `scipy`
# 2. Create a dataframe from the data contained in *income_data.csv* using `pandas`

# %%
# Code here

import pandas as pd
from scipy import stats 

df = pd.read_csv('./income_data.csv')
df.head()
# Out:
#           job  type  income  education  prestige
# 0  accountant  prof      62         86        82
# 1       pilot  prof      72         76        83
# 2   architect  prof      75         92        90
# 3      author  prof      55         90        76
# 4     chemist  prof      64         86        90

# %% [markdown]
# 3. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *income* and *education*

# %%
# Code here
r, p = stats.pearsonr(df["income"], df["education"])
print ("Income and education")
print (f"Pearson's correlation coefficient (r): {r:.3f}")
print (f"p value: {p:.3f}")
# Out:
# Income and education
# Pearson's correlation coefficient (r): 0.725
# p value: 0.000

# %% [markdown]
# 3. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *income* and *prestige*

# %%
# Code here

cor_coef, p_val = stats.pearsonr(df["income"], df["prestige"])
print (f"Pearson's correlation coefficient: {cor_coef:.3f}")
print(f"p-value: {p_val:.3f}")
# Out:
# Pearson's correlation coefficient: 0.838
# p-value: 0.000

# %% [markdown]
# 4. Calculate and display Pearson's **correlation coefficients** and the **p-values** for *education* and *prestige*

# %%
# Code here

c,p = stats.pearsonr(df["education"], df["prestige"])
print (f"Pearson correlation coefficient (p): {c:.3f}")
print (f"p-value: {p:.3f}")
# Out:
# Pearson correlation coefficient (p): 0.852
# p-value: 0.000

# %% [markdown]
# 5. In the empty `Markdown` cell below, explain the following for **each of the calculated correlation coefficients**
#     - The **strength** and **direction** of the correlation
#     - The **statistical significance** of the test (**p-value**); emphasize if we can trust the correlation test or not, and why

# %% [markdown]
# Pearson's correlation coefficent measures the linear relationship between datasets, spanning from -1 to 1, 0 meaning no corelation. Postivie correlations mean that as x increases, y increases. Negative correlations mean that as x increases, y decreases. A high coefficent (1 or -1) represents a strong correlation.
# <br>
# The p-value represents the statisitcal strength of the test, or how strongly the data contradicts the null hypothesis. IN other words, the p-valye describes how likely it is that your data occured by random chance. Smaller p-values mean results are less consistent with the null and could support the alternative hypothesis/less likley that results are random --> reject null hypothesis.
#
# <br>
# <i><b>Income and education</b></i><br>
# Pearson's correlation coefficient (r): 0.725
# p value: 0.000
#     <ul>
#         <li> Strong positive correlation because the coefficient is closer to 1 and positive
#         <li>Reject null hypothesis- it is likely that these are correlated. I believe this is trustworthy since if you just look at the data we are analyzing, it is likely/logical to believe that there is a correlation between them.
#     </ul>
#
# <br>
# <i><b>Income and prestige</b></i><br>
# Pearson's correlation coefficient: 0.838
# p-value: 0.000
#     <ul>
#         <li>Very strong postivie correlation- the coefficient is postive and close to 1.
#         <li>Reject null hypothesis- it is lilkey that a job with higher income has more prestige. This test can be trusted because there are several data points that are taken into consideration and the p-value is so small that the program cuts off before it gets to an actual value- the p value is not exactly 0, but it is still very very small.
#     </ul>
#
# <br>
# <i><b>Education and prestige</b></i><br>
# Pearson correlation coefficient (p): 0.852
# p-value: 0.000
#     <ul>
#         <li> Very strong postivie correlation- the coefficient is postive and really close to 1.
#         <li>REject null hypothesis- these results can be trusted if we think about it logically. Income and education have a strong positive correlation, and income and prestige have a strong postive correlation. Therefore, it makes sense that education and prestige are also correlated.
#     </ul>
# <br><br>

# %% [markdown]
# In the empty `Markdown` cell below, answer the following question:
#
# 6. Pearson's correlation coefficient OR covariance can both be used to measure the direction of the relationship between two variables (e.g., education and income). Explain why Pearson's correlation coefficient may be better than covariance.

# %% [markdown]
# Covariance is the mean/expected value of the product of 2 variable's deviations. It can be postive, zero, or negative, and the larger the value, the more positive/negative the covariance will be. Pearson's correlation coefficient may be better than covariance because it has a range from -1 to 1. It is considered a standarized measure of strength, and it returns how much we can trust the data (p-value). It meaures strength and direction, making it easier and better in many cases, including this one.

# %% [markdown]
# 7. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment3.ipynb**
#     - Replace '**Last**' and '**First**' with your name
