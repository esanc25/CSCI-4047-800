# %% [markdown]
# # In-Class Example
# I am reading data from `AllPokemon.csv` into a data frame.
#
# ## Steps:
# - Verify `Python` and `pip` are installed (`python --version` or `pip --version`).
# - Install the `pandas` package with `pip install pandas` in the terminal.
# - Write the program (see below).

# %% [markdown]
# >this is blockcode we are applying classifaction here
# <br>
# >use the less than symbold

# %%
import pandas as pd

df = pd.read_csv("./AllPokemon.csv")

df.head()

# %%
#Display unique names 

print(df['Name'].nunique())
    #nunique --> number of unique values

# %%
#number of type2 unique vakyes
print(list(df['Type2'].unique()))

# %%
#rows, columns of data 
print(df.shape)

# %%
#describes type of data 
print(df.info())
    # do not forget the () inside the big ()- this will give you different result

# %%
#statistic information 
#count, mean, that kinda info 

print(df.describe())
